# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

import sys
sys.path.append("../")

from analytics.classification_aux import em2_classification_cached
from classification import twopoisson_em
from classification import visualization

from analytics.classification_aux import extract_train_test, print_results, compare_results
from aux.events_io import load_events, store_events
from testing.user_testing import *

##########################################

import logging
from imp import reload
reload(logging)
fmt = '[%(process)4d][%(asctime)s][%(levelname)-5s][%(module)s:%(lineno)d/%(funcName)s] %(message)s'
logging.basicConfig(format=fmt, level=logging.INFO, datefmt='%I:%M:%S')

# %matplotlib inline

# %% [markdown]
# # STRUNK&WHITE DATA PREPARATION

# %%
user2features = pd.read_csv("../../data/badges/covariates.tsv", sep="\t")
samples = pd.read_csv("../../data/badges_strunkwhite.tsv", sep="\t")

# %%
city_features = ["c0", "c1", "c2", "c3", "c4"]
state_features = ["s0", "s1", "s2", "s3", "s4"]
user_features = ["age", "upvotes",  "views", "downvotes", "comments"]  #, "reputation"
selected_features = user_features+city_features+state_features
features, train_ids, test_ids = extract_train_test(samples, user2features[["id"]+selected_features], 
                                                   max_train=10000, max_test=0)

# %% [markdown]
# # EM2

# %%
nhst_preds_file = "../../data/badges_strunkwhite_nhst_preds.tsv"

# %%
train_preds, test_preds, em2_results = em2_classification_cached(features, samples, train_ids, test_ids, 
                                                                   sigma=1, kappa=1,
                                                                   nhst_preds_file=nhst_preds_file)
# Out:
# [7934][09:02:01][INFO ][classification_aux:56/em2_classification_cached] NHST predictions loaded from ../../data/badges_strunkwhite_nhst_preds.tsv
# [7934][09:02:01][INFO ][classification_aux:77/em2_classification_cached] Clustering
# [7934][09:02:01][INFO ][nhst_with_em2:93/two_step_classification] [two_step_classification] EM2 refining started.
# [7934][09:02:07][INFO ][em2:164/normal_em] [em2][normal_em] iteration=0 ll=-34221.0770129 prev_ll=None
# [7934][09:02:11][INFO ][em2:164/normal_em] [em2][normal_em] iteration=1 ll=-33893.8726232 prev_ll=-34221.0770129
# [7934][09:02:15][INFO ][em2:164/normal_em] [em2][normal_em] iteration=2 ll=-32333.8854675 prev_ll=-33893.8726232
# [7934][09:02:19][INFO ][em2:164/normal_em] [em2][normal_em] iteration=3 ll=-28788.0043549 prev_ll=-32333.8854675
# [7934][09:02:23][INFO ][em2:164/normal_em] [em2][normal_em] iteration=4 ll=-26670.3648122 prev_ll=-28788.0043549
# [7934][09:02:28][INFO ][em2:164/normal_em] [em2][normal_em] iteration=5 ll=-25366.3016534 prev_ll=-26670.3648122
# [7934][09:02:34][INFO ][em2:164/normal_em] [em2][normal_em] iteration=6 ll=-24897.478919 prev_ll=-25366.3016534
# [7934][09:02:39][INFO ][em2:164/normal_em] [em2][normal_em] iteration=7 ll=-24669.7741631 prev_ll=-24897.478919
# [7934][09:02:45][INFO ][em2:164/normal_em] [em2][normal_em] iteration=8 ll=-24648.9181838 prev_ll=-24669.7741631
# [7934][09:02:50][INFO ][em2:164/normal_em] [em2][normal_em] iteration=9 ll=-24646.8623847 prev_ll=-24648.9181838
# [7934][09:02:54][INFO ][em2:164/normal_em] [em2][normal_em] iteration=10 ll=-24646.2726834 prev_ll=-24646.8623847
# [7934][09:02:58][INFO ][em2:164/normal_em] [em2][normal_em] iteration=11 ll=-24646.1125635 prev_ll=-24646.2726834
# [7934][09:02:58][INFO ][em2:167/normal_em] [em2][normal_em] EM has converged in 12 iterations: ll=-24646.1125635 prev_ll=-24646.2726834!

# %% [markdown]
# ### Results visualization

# %%
print("available features:", list(enumerate(features.columns[1:])))
# Out:
# available features: [(0, 'age'), (1, 'upvotes'), (2, 'downvotes'), (3, 'comments'), (4, 'reputation'), (5, 'c0'), (6, 'c1'), (7, 'c2'), (8, 'c3'), (9, 'c4'), (10, 's0'), (11, 's1'), (12, 's2'), (13, 's3'), (14, 's4')]

# %%
#features to be plotted
features_no, features_names = zip(*[(0, 'age'), (1, 'upvotes')]) 
features_no, features_names = list(features_no), list(features_names)

# %%
#PLOT NHST RESULTS
nhst_train_preds = em2_results["nhst_preds"]

visualization.pyplot_reset()
visualization.plot_groups(features, features_names, 
                          train_ids, nhst_train_preds, 
                          train_marker = "+", test_marker="x",
                          #ylabel="log(%s)" % features_names[1], 
                          plot_legend=False, s=10, plot_densities=True)

print_results(nhst_train_preds)
# Out:
# train_preds0 = 2223 = 0.82
# train_preds1 = 501 = 0.18
# test_preds0 = 0 = 0.00
# test_preds1 = 0 = 0.00

# %%
#FINAL RESULTS

visualization.pyplot_reset()
visualization.plot_groups(features, features_names, 
                          train_ids, train_preds, 
                          test_ids, test_preds,
                          train_marker = "+", test_marker="x",
                          #ylabel="log(%s)" % features_names[1], 
                          plot_legend=True, s=10, plot_densities=False)
visualization.plot_bivariate(em2_results["mu"][0,features_no], 
                             em2_results["ss"][0][np.ix_(features_no,features_no)], 
                             cmap="Blues")#, limits=(1,4,10,60))
visualization.plot_bivariate(em2_results["mu"][1,features_no], 
                             em2_results["ss"][1][np.ix_(features_no,features_no)], 
                             cmap="Reds")#, limits=(1,4,10,60))
#pyplot.xlim((1,4))

print_results(train_preds, test_preds)
# Out:
# train_preds0 = 1251 = 0.46
# train_preds1 = 1473 = 0.54
# test_preds0 = 0 = 0.00
# test_preds1 = 0 = 0.00

# %%
compare_results(nhst_train_preds, train_preds)
# Out:
# pearsonr= (0.05986403917470904, 0.0017732777716714452)
# G: 304 1054 1169 197
# p1= 0.183920704845815
# p2= 0.5407488986784141
# N= 2724
# agreement= 0.498531571219
# p-value= 0.004666666666666667

# %%
#PLOT INITIAL ASSIGNMENTS 
#init_train_preds, init_test_preds = em2_results["init_train"], em2_results["init_test"]

#visualization.pyplot_reset()
#visualization.plot_groups(features, features_names, 
#                          train_ids, init_train_preds, 
#                          test_ids, init_test_preds, 
#                          train_marker = "+", test_marker="x",
#                          #ylabel="log(%s)" % features_names[1], 
#                          plot_legend=True, s=10, plot_densities=True)

# %% [markdown]
# # twopoisson_em

# %%
train_preds2, test_preds2 = twopoisson_em.twopoisson_em_classification(features, samples, 
                                                                       train_ids, test_ids, 
                                                                       badge_name="switch_time")
# Out:
# [7934][09:03:18][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [7934][09
print_results(train_preds2, test_preds2)
compare_results(train_preds2, train_preds)
compare_results(test_preds2, test_preds)
# Out:
# train_preds0 = 1725 = 0.63
# train_preds1 = 998 = 0.37
# test_preds0 = 0 = 0.00
# test_preds1 = 0 = 0.00
#
# pearsonr= (nan, 1.0)
# G: 527 780 946 471
# p1= 0.36637298091042586
# p2= 0.5407488986784141
# N= 2724
# agreement= 0.479809104258
# p-value= 0.8306666666666667

# %%
visualization.pyplot_reset()
visualization.plot_groups(features, features_names, 
                          train_ids, train_preds2,
                          test_ids, test_preds2,
                          train_marker = "+", test_marker="x",
                          plot_legend=True, s=10, plot_densities=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ace91628f2f3> in <module>()
#       4                           test_ids, test_preds2,
#       5                           train_marker = "+", test_marker="x",
# ----> 6                           plot_legend=True, s=10, plot_densities=True)
#
# /home/tomaszku/prj_badges2/src/classification/visualization.py in plot_groups(features, feature_names, train_ids, train_group, test_ids, test_group, train_marker, test_marker, xlabel, ylabel, plot_legend, plot_densities, **kwargs)
#      65         x = x_all[[id2pos[i] for i in ids] ,:]
#      66         y = x[:,1] if len(x[0])>=2 else np.zeros(len(x))
# ---> 67         sns.kdeplot(x[:,0], y, n_levels=4, cmap="Reds", lw=4)
#      68
#      69         ids, weights = train_ids+test_ids, 1.0-np.asarray(list(train_group)+list(test_group))
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, ax, **kwargs)
#     598         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     599                                 kernel, bw, gridsize, cut, clip, legend,
# --> 600                                 ax, **kwargs)
#     601     else:
#     602         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/seaborn/distributions.py in _bivariate_kdeplot(x, y, filled, fill_lowest, kernel, bw, gridsize, cut, clip, axlabel, ax, **kwargs)
#     381     kwargs["cmap"] = cmap
#     382     contour_func = ax.contourf if filled else ax.contour
# --> 383     cset = contour_func(xx, yy, z, n_levels, **kwargs)
#     384     if filled and not fill_lowest:
#     385         cset.collections[0].set_alpha(0)
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in contour(self, *args, **kwargs)
#    5642             self.cla()
#    5643         kwargs['filled'] = False
# -> 5644         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5645     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    5646
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#    1422         are described in QuadContourSet.contour_doc.
#    1423         """
# -> 1424         ContourSet.__init__(self, ax, *args, **kwargs)
#    1425
#    1426     def _process_args(self, *args, **kwargs):
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#     862
#     863         self._process_args(*args, **kwargs)
# --> 864         self._process_levels()
#     865
#     866         if self.colors is not None:
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/matplotlib/contour.py in _process_levels(self)
#    1200         # The following attributes are no longer needed, and
#    1201         # should be deprecated and removed to reduce confusion.
# -> 1202         self.vmin = np.amin(self.levels)
#    1203         self.vmax = np.amax(self.levels)
#    1204
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims)
#    2350
#    2351     return _methods._amin(a, axis=axis,
# -> 2352                           out=out, **kwargs)
#    2353
#    2354
#
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity
