# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

import sys
sys.path.append("../")

from analytics.classification_aux import em2_classification_cached
from classification import twopoisson_em
from classification import visualization
from classification.logistic import logistic_regression

from analytics.classification_aux import extract_train_test, print_results, compare_results
from aux.events_io import load_events, store_events
from testing.user_testing import *

##########################################

import logging
from imp import reload
reload(logging)
fmt = '[%(process)4d][%(asctime)s][%(levelname)-5s][%(module)s:%(lineno)d/%(funcName)s] %(message)s'
logging.basicConfig(format=fmt, level=logging.INFO, datefmt='%I:%M:%S')

# %matplotlib inline

# %% [markdown]
# # COPY EDITOR DATA PREPARATION

# %%
user2features = pd.read_csv("../../data/badges/covariates.tsv", sep="\t")
samples = pd.read_csv("../../data/badges_copyeditor.tsv", sep="\t")
reputation = pd.read_csv("../../data/user_reputation.tsv", sep="\t")

# %%
city_features = ["c0", "c1", "c2", "c3", "c4"]
state_features = ["s0", "s1", "s2", "s3", "s4"]
user_features = ["age", "upvotes",  "views", "downvotes", "comments"]  #, "reputation"
selected_features = user_features+city_features+state_features
features, train_ids, test_ids = extract_train_test(samples, user2features[["id"]+selected_features], 
                                                   max_train=1000, max_test=10000)

# %%
test_ids = sorted(set(test_ids).intersection(list(reputation[~reputation["rep1500"].isnull()]["id"])))

# %%
test_ids2 = test_ids
test_ids = []

# %% [markdown]
# # EM2

# %%
nhst_preds_file = "../../data/badges_copyeditor_nhst_preds.tsv"

# %%
train_preds, test_preds, em2_results = em2_classification_cached(features, samples, train_ids, test_ids, 
                                                                   sigma=1, kappa=10,
                                                                   nhst_preds_file=nhst_preds_file)
# Out:
# [28375][12:02:07][INFO ][classification_aux:56/em2_classification_cached] NHST predictions loaded from ../../data/badges_copyeditor_nhst_preds.tsv
# [28375][12:02:07][INFO ][classification_aux:77/em2_classification_cached] Clustering
# [28375][12:02:07][INFO ][nhst_with_em2:93/two_step_classification] [two_step_classification] EM2 refining started.
# [28375][12:02:09][INFO ][em2:164/normal_em] [em2][normal_em] iteration=0 ll=-6172.89212634 prev_ll=None
# [28375][12:02:11][INFO ][em2:164/normal_em] [em2][normal_em] iteration=1 ll=-6050.41830645 prev_ll=-6172.89212634
# [28375][12:02:12][INFO ][em2:164/normal_em] [em2][normal_em] iteration=2 ll=-5801.92030352 prev_ll=-6050.41830645
# [28375][12:02:14][INFO ][em2:164/normal_em] [em2][normal_em] iteration=3 ll=-5467.2619697 prev_ll=-5801.92030352
# [28375][12:02:16][INFO ][em2:164/normal_em] [em2][normal_em] iteration=4 ll=-5156.951301 prev_ll=-5467.2619697
# [28375][12:02:19][INFO ][em2:164/normal_em] [em2][normal_em] iteration=5 ll=-4821.96345784 prev_ll=-5156.951301
# [28375][12:02:21][INFO ][em2:164/normal_em] [em2][normal_em] iteration=6 ll=-4739.42940267 prev_ll=-4821.96345784
# [28375][12:02:22][INFO ][em2:164/normal_em] [em2][normal_em] iteration=7 ll=-4724.59302718 prev_ll=-4739.42940267
# [28375][12:02:23][INFO ][em2:164/normal_em] [em2][normal_em] iteration=8 ll=-4676.0162125 prev_ll=-4724.59302718
# [28375][12:02:24][INFO ][em2:164/normal_em] [em2][normal_em] iteration=9 ll=-4492.92709937 prev_ll=-4676.0162125
# [28375][12:02:25][INFO ][em2:164/normal_em] [em2][normal_em] iteration=10 ll=-4374.27466201 prev_ll=-4492.92709937
# [28375][12:02:26][INFO ][em2:164/normal_em] [em2][normal_em] iteration=11 ll=-4315.90341297 prev_ll=-4374.27466201
# [28375][12:02:28][INFO ][em2:164/normal_em] [em2][normal_em] iteration=12 ll=-4266.76382934 prev_ll=-4315.90341297
# [28375][12:02:29][INFO ][em2:164/normal_em] [em2][normal_em] iteration=13 ll=-4181.35974965 prev_ll=-4266.76382934
# [28375][12:02:30][INFO ][em2:164/normal_em] [em2][normal_em] iteration=14 ll=-4069.96853202 prev_ll=-4181.35974965
# [28375][12:02:31][INFO ][em2:164/normal_em] [em2][normal_em] iteration=15 ll=-4065.8943539 prev_ll=-4069.96853202
# [28375][12:02:33][INFO ][em2:164/normal_em] [em2][normal_em] iteration=16 ll=-4065.65666171 prev_ll=-4065.8943539
# [28375][12:02:34][INFO ][em2:164/normal_em] [em2][normal_em] iteration=17 ll=-4065.6085191 prev_ll=-4065.65666171
# [28375][12:02:36][INFO ][em2:164/normal_em] [em2][normal_em] iteration=18 ll=-4065.60626041 prev_ll=-4065.6085191
# [28375][12:02:36][INFO ][em2:167/normal_em] [em2][normal_em] EM has converged in 19 iterations: ll=-4065.60626041 prev_ll=-4065.6085191!

# %%
train_preds3, test_preds3 = logistic_regression(features, train_ids, test_ids2, train_preds)

# %% [markdown]
# ### Results visualization

# %%
print("available features:", list(enumerate(features.columns[1:])))
# Out:
# available features: [(0, 'age'), (1, 'upvotes'), (2, 'views'), (3, 'downvotes'), (4, 'comments'), (5, 'c0'), (6, 'c1'), (7, 'c2'), (8, 'c3'), (9, 'c4'), (10, 's0'), (11, 's1'), (12, 's2'), (13, 's3'), (14, 's4')]

# %%
#features to be plotted
features_no, features_names = zip(*[(0, 'age'), (2, 'views')]) 
features_no, features_names = list(features_no), list(features_names)

# %%
#PLOT Logistic regression RESULTS
reload(visualization)

visualization.pyplot_reset()
visualization.plot_groups(features, features_names, 
                          train_ids, train_preds3,
                          test_ids2, test_preds3,
                          train_marker = "+", test_marker="x",
                          #ylabel="log(%s)" % features_names[1], 
                          plot_legend=True, s=30, plot_densities=True)

pyplot.gcf().subplots_adjust(bottom=0.15, left=0.15)# right=0.85, left=0.15)
pyplot.xlim((15,55)); pyplot.ylim((4,12)); pyplot.ylabel("log(%s)" % features_names[1])
pyplot.savefig("../../data/badges_copyeditor_logistic_preds1.pdf")

# %%
sum(test_preds3>0.5)/len(test_preds3)
# Out:
# 0.36304816678648455

# %%
#PLOT NHST RESULTS
nhst_train_preds = em2_results["nhst_preds"]

visualization.pyplot_reset()
visualization.plot_groups(features, features_names, 
                          train_ids, nhst_train_preds, 
                          train_marker = "+", test_marker="x",
                          #ylabel="log(%s)" % features_names[1], 
                          plot_legend=False, s=10, plot_densities=True)

pyplot.gcf().subplots_adjust(bottom=0.15, left=0.15)# right=0.85, left=0.15)
pyplot.xlim((15,55)); pyplot.ylim((4,12)); pyplot.ylabel("log(%s)" % features_names[1])
pyplot.savefig("../../data/badges_copyeditor_nhst_preds1.pdf")

print_results(nhst_train_preds)
# Out:
# train_preds0 = 233 = 0.47
# train_preds1 = 265 = 0.53
# test_preds0 = 0 = 0.00
# test_preds1 = 0 = 0.00

# %%
#FINAL RESULTS

visualization.pyplot_reset()
visualization.plot_groups(features, features_names, 
                          train_ids, train_preds, 
                          test_ids, test_preds,
                          train_marker = "+", test_marker="x",
                          #ylabel="log(%s)" % features_names[1], 
                          plot_legend=False, s=10, plot_densities=False)
visualization.plot_bivariate(em2_results["mu"][0,features_no], 
                             em2_results["ss"][0][np.ix_(features_no,features_no)], 
                             cmap="Blues")#, limits=(1,4,10,60))
visualization.plot_bivariate(em2_results["mu"][1,features_no], 
                             em2_results["ss"][1][np.ix_(features_no,features_no)], 
                             cmap="Reds")#, limits=(1,4,10,60))
#pyplot.xlim((1,4))

pyplot.gcf().subplots_adjust(bottom=0.15, left=0.15)# right=0.85, left=0.15)
pyplot.xlim((15,55)); pyplot.ylim((4,12)); pyplot.ylabel("log(%s)" % features_names[1])
pyplot.savefig("../../data/badges_copyeditor_2sb_preds1.pdf")

print_results(train_preds, test_preds)
# Out:
# train_preds0 = 263 = 0.53
# train_preds1 = 235 = 0.47
# test_preds0 = 0 = 0.00
# test_preds1 = 0 = 0.00

# %%
compare_results(nhst_train_preds, train_preds)
# Out:
# pearsonr= (0.07961702922223686, 0.075884575709086147)
# G: 135 133 100 130
# p1= 0.5321285140562249
# p2= 0.4718875502008032
# N= 498
# agreement= 0.538152610442
# p-value= 0.032

# %%
#PLOT INITIAL ASSIGNMENTS 
#init_train_preds, init_test_preds = em2_results["init_train"], em2_results["init_test"]

#visualization.pyplot_reset()
#visualization.plot_groups(features, features_names, 
#                          train_ids, init_train_preds, 
#                          test_ids, init_test_preds, 
#                          train_marker = "+", test_marker="x",
#                          #ylabel="log(%s)" % features_names[1], 
#                          plot_legend=True, s=10, plot_densities=True)

# %% [markdown]
# # twopoisson_em

# %%
train_preds2, test_preds2 = twopoisson_em.twopoisson_em_classification(features, samples, 
                                                                       train_ids, test_ids2, 
                                                                       badge_name="switch_time")
# Out:
# [28375][12:02:58][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/poisson_ll.py:34: RuntimeWarning: invalid value encountered in log
#   return (a*log(b) - (a+n)*log(lt+b) + loggamma(a+n) - loggamma(a) )
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [28375][12:03:11][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:03:12][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=93715.2 z1=0.604845786963
# [28375][12:03:13][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=2 LL=nan z1=nan
# [28375][12:03:15][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=3 LL=93801.0 z1=0.60421666861
# [28375][12:03:25][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=4 LL=94743.3 z1=0.598646854867
# [28375][12:03:25][INFO ][twopoisson_em:62/fitting] [twopoisson_em][fitting] The algorithm has not converged in 5 iteratons.
# [28375][12:03:25][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/poisson_ll.py:34: RuntimeWarning: invalid value encountered in log
#   return (a*log(b) - (a+n)*log(lt+b) + loggamma(a+n) - loggamma(a) )
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [28375][12:03:45][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:03:46][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=116671.1 z1=0.874961982949
# ../clustering/poisson_ll.py:38: RuntimeWarning: divide by zero encountered in log
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/poisson_ll.py:38: RuntimeWarning: invalid value encountered in multiply
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/twopoisson_em_with_covariates.py:100: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# ../clustering/twopoisson_em_with_covariates.py:123: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# [28375][12:03:47][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=2 LL=nan z1=nan
# [28375][12:03:48][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=3 LL=116591.2 z1=0.999999999996
# [28375][12:03:48][WARNING][twopoisson_em:58/fitting] [twopoisson_em][fitting] algorithm got stuck with one class (z1=0.999999999996). interrupting.
# [28375][12:03:48][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/poisson_ll.py:34: RuntimeWarning: invalid value encountered in log
#   return (a*log(b) - (a+n)*log(lt+b) + loggamma(a+n) - loggamma(a) )
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [28375][12:04:07][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=117937.9 z1=0.845327116732
# ../clustering/poisson_ll.py:38: RuntimeWarning: divide by zero encountered in log
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/poisson_ll.py:38: RuntimeWarning: invalid value encountered in multiply
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/twopoisson_em_with_covariates.py:100: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# ../clustering/twopoisson_em_with_covariates.py:123: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# [28375][12:04:08][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=117797.3 z1=0.999999999977
# [28375][12:04:08][WARNING][twopoisson_em:58/fitting] [twopoisson_em][fitting] algorithm got stuck with one class (z1=0.999999999977). interrupting.
# [28375][12:04:08][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/poisson_ll.py:34: RuntimeWarning: invalid value encountered in log
#   return (a*log(b) - (a+n)*log(lt+b) + loggamma(a+n) - loggamma(a) )
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [28375][12:04:28][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=118011.5 z1=0.850708527573
# ../clustering/poisson_ll.py:38: RuntimeWarning: divide by zero encountered in log
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/poisson_ll.py:38: RuntimeWarning: invalid value encountered in multiply
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/twopoisson_em_with_covariates.py:100: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# ../clustering/twopoisson_em_with_covariates.py:123: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# [28375][12:04:29][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=117933.9 z1=0.999999999988
# [28375][12:04:29][INFO ][twopoisson_em:55/fitting] [twopoisson_em][fitting] The algorithm has converged in 2 iteratons.
# [28375][12:04:29][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# [28375][12:04:39][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:04:40][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=116701.0 z1=0.999999999997
# [28375][12:04:40][WARNING][twopoisson_em:58/fitting] [twopoisson_em][fitting] algorithm got stuck with one class (z1=0.999999999997). interrupting.
# [28375][12:04:40][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# ../clustering/twopoisson_em_with_covariates.py:18: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/poisson_ll.py:34: RuntimeWarning: invalid value encountered in log
#   return (a*log(b) - (a+n)*log(lt+b) + loggamma(a+n) - loggamma(a) )
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [28375][12:04:58][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=118058.1 z1=0.85453988548
# ../clustering/poisson_ll.py:38: RuntimeWarning: divide by zero encountered in log
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/poisson_ll.py:38: RuntimeWarning: invalid value encountered in multiply
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/twopoisson_em_with_covariates.py:100: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# ../clustering/twopoisson_em_with_covariates.py:123: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# [28375][12:04:59][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=117982.6 z1=0.999999999992
# [28375][12:04:59][INFO ][twopoisson_em:55/fitting] [twopoisson_em][fitting] The algorithm has converged in 2 iteratons.
# [28375][12:04:59][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# [28375][12:05:11][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:05:12][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=99062.2 z1=0.643256302509
# [28375][12:05:14][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=2 LL=100232.1 z1=0.631777581293
# [28375][12:05:15][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=3 LL=100240.8 z1=0.631769640929
# [28375][12:05:15][INFO ][twopoisson_em:55/fitting] [twopoisson_em][fitting] The algorithm has converged in 4 iteratons.
# [28375][12:05:15][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/poisson_ll.py:34: RuntimeWarning: invalid value encountered in log
#   return (a*log(b) - (a+n)*log(lt+b) + loggamma(a+n) - loggamma(a) )
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [28375][12:05:33][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:05:34][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=116678.4 z1=0.874434159447
# ../clustering/poisson_ll.py:38: RuntimeWarning: divide by zero encountered in log
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/poisson_ll.py:38: RuntimeWarning: invalid value encountered in multiply
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/twopoisson_em_with_covariates.py:100: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# ../clustering/twopoisson_em_with_covariates.py:123: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# [28375][12:05:35][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=2 LL=nan z1=nan
# [28375][12:05:37][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=3 LL=116555.7 z1=0.999999999994
# [28375][12:05:37][WARNING][twopoisson_em:58/fitting] [twopoisson_em][fitting] algorithm got stuck with one class (z1=0.999999999994). interrupting.
# [28375][12:05:37][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/_minimize.py:381: RuntimeWarning: Method COBYLA does not use gradient information (jac).
#   RuntimeWarning)
# /home/tomaszku/anaconda3/lib/python3.5/site-packages/scipy/optimize/cobyla.py:258: ComplexWarning: Casting complex values to real discards the imaginary part
#   dinfo=info)
# ../clustering/poisson_ll.py:34: RuntimeWarning: invalid value encountered in log
#   return (a*log(b) - (a+n)*log(lt+b) + loggamma(a+n) - loggamma(a) )
# ../clustering/twopoisson_em_with_covariates.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 0] = np.exp(LL - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:104: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.z[u, 1] = np.exp(LL01 - logsumexp([LL, LL01]))
# ../clustering/twopoisson_em_with_covariates.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(total)
# [28375][12:05:57][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:05:58][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=116620.8 z1=0.863847590652
# ../clustering/poisson_ll.py:38: RuntimeWarning: divide by zero encountered in log
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/poisson_ll.py:38: RuntimeWarning: invalid value encountered in multiply
#   vs = [zu * (PoissonLL.user_LL(a, b, n, lt) + np.log(piu)) for (n, lt), zu, piu in zip(self.users, self.z, self.pi)]
# ../clustering/twopoisson_em_with_covariates.py:100: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# ../clustering/twopoisson_em_with_covariates.py:123: RuntimeWarning: divide by zero encountered in log
#   LL   = PoissonLL.user_LL(self.a,  self.b,  n,  lt) + np.log(self.pi[u, 0])
# [28375][12:05:59][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=2 LL=nan z1=nan
# [28375][12:06:00][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=3 LL=116445.1 z1=0.999999999982
# [28375][12:06:00][WARNING][twopoisson_em:58/fitting] [twopoisson_em][fitting] algorithm got stuck with one class (z1=0.999999999982). interrupting.
# [28375][12:06:00][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# [28375][12:06:10][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:06:11][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=116676.7 z1=1.0
# [28375][12:06:11][WARNING][twopoisson_em:58/fitting] [twopoisson_em][fitting] algorithm got stuck with one class (z1=1.0). interrupting.
# [28375][12:06:11][INFO ][twopoisson_em:39/fitting] [twopoisson_em][fitting] TwoPoissonEMCOV fitting started.
# [28375][12:06:24][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=0 LL=nan z1=nan
# [28375][12:06:25][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=1 LL=86876.4 z1=0.569695413945
# [28375][12:06:26][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=2 LL=88116.5 z1=0.564239641749
# [28375][12:06:27][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=3 LL=nan z1=nan
# [28375][12:06:28][INFO ][twopoisson_em:53/fitting] [twopoisson_em][fitting] iteration=4 LL=86996.6 z1=0.567822175587
# [28375][12:06:28][INFO ][twopoisson_em:62/fitting] [twopoisson_em][fitting] The algorithm has not converged in 5 iteratons.
# [28375][12:06:28][INFO ][twopoisson_em:129/twopoisson_em_classification] [twopoisson_em] >>>LL=100240.8

# %%
print_results(train_preds2, test_preds2)
compare_results(train_preds2, train_preds)
compare_results(test_preds2, test_preds)
# Out:
# train_preds0 = 184 = 0.37
# train_preds1 = 314 = 0.63
# test_preds0 = 1391 = 1.00
# test_preds1 = 0 = 0.00
#
# pearsonr= (0.074797323387789119, 0.095452324893434748)
# G: 157 106 78 157
# p1= 0.6305220883534136
# p2= 0.4718875502008032
# N= 498
# agreement= 0.528112449799
# p-value= 0.056666666666666664

# %%
visualization.pyplot_reset()
visualization.plot_groups(features, features_names, 
                          train_ids, train_preds2,
                          test_ids, test_preds2,
                          train_marker = "+", test_marker="x",
                          plot_legend=False, s=10, plot_densities=True)

pyplot.gcf().subplots_adjust(bottom=0.15, left=0.15)# right=0.85, left=0.15)
pyplot.xlim((15,55)); pyplot.ylim((4,12)); pyplot.ylabel("log(%s)" % features_names[1])
pyplot.savefig("../../data/badges_copyeditor_2p_preds1.pdf")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-dbc33f298733> in <module>()
#       4                           test_ids, test_preds2,
#       5                           train_marker = "+", test_marker="x",
# ----> 6                           plot_legend=False, s=10, plot_densities=True)
#       7
#       8 pyplot.gcf().subplots_adjust(bottom=0.15, left=0.15)# right=0.85, left=0.15)
#
# /home/tomaszku/prj_badges2/src/classification/visualization.py in plot_groups(features, feature_names, train_ids, train_group, test_ids, test_group, train_marker, test_marker, xlabel, ylabel, plot_legend, plot_densities, **kwargs)
#      30
#      31     assert len(train_ids)==len(train_group)
# ---> 32     assert len(test_group)==0 or len(test_ids)==len(test_group)
#      33     assert len(feature_names)==2
#      34
#
# AssertionError:
